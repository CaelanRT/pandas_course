# %%
import numpy as np
import pandas as pd

# %%
string_series = pd.Series(['Monday', 'Tuesday', 'Wednesday', 'Thursday', 'Friday'])
string_series
# Out:
# 0       Monday
# 1      Tuesday
# 2    Wednesday
# 3     Thursday
# 4       Friday
# dtype: str

# %%
string_series.str.contains("Mon")
# Out:
# 0     True
# 1    False
# 2    False
# 3    False
# 4    False
# dtype: bool

# %%
# can thain these, the str.*() method returns a series so need to call .str again
# convert to upper or lower first
string_series.str.upper().str.contains("MON")
# Out:
# 0     True
# 1    False
# 2    False
# 3    False
# 4    False
# dtype: bool

# %%
string_series.str.strip('day')
# Out:
# 0       Mon
# 1      Tues
# 2    Wednes
# 3     Thurs
# 4       Fri
# dtype: str

# %%
string_series.str.split('d', expand=True)
# Out:
#        0    1    2
# 0    Mon   ay  NaN
# 1   Tues   ay  NaN
# 2     We  nes   ay
# 3  Thurs   ay  NaN
# 4    Fri   ay  NaN
