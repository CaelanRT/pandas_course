# %%
import numpy as np
import pandas as pd

# %%
my_series = pd.Series([1, 0, 2, 3, 4], index=['Monday', 'Tuesday', 'Wednesday', 'Thursday', 'Friday'] )
my_series
# Out:
# Monday       1
# Tuesday      0
# Wednesday    2
# Thursday     3
# Friday       4
# dtype: int64

# %%
# can sort values or indexes

# %%
#not in place by default need: inplace=True
my_series.sort_values(ascending=False)
# Out:
# Friday       4
# Thursday     3
# Wednesday    2
# Monday       1
# Tuesday      0
# dtype: int64

# %%
# can store sorted series in a var
my_series.sort_index(ascending=False)
# Out:
# Wednesday    2
# Tuesday      0
# Thursday     3
# Monday       1
# Friday       4
# dtype: int64
