# %%
import pandas as pd
import numpy as np

# %%
my_series = pd.Series(range(5), index=['Monday', 'Tuesday', 'Wednesday', 'Thursday', 'Friday'] )
my_series
# Out:
# Monday       0
# Tuesday      1
# Wednesday    2
# Thursday     3
# Friday       4
# dtype: int64

# %%
my_series.iloc[[1, 2, 4]]
# Out:
# Tuesday      1
# Wednesday    2
# Friday       4
# dtype: int64

# %%
my_series.iloc[1:4]
# Out:
# Tuesday      1
# Wednesday    2
# Thursday     3
# dtype: int64
