# %%
import numpy as np
import pandas as pd

# %%
array = np.arange(5)

series = pd.Series(array)

# %%
pd.Series(np.arange(5), name='Test Array')

# this error as you can only work with 1d arrays
# pd.Series(np.arange(6).reshape(3,2), name='Test Array')
# Out:
# 0    0
# 1    1
# 2    2
# 3    3
# 4    4
# Name: Test Array, dtype: int64

# %%
series.values
# Out:
# array([0, 1, 2, 3, 4])

# %%
series.values.mean()
# Out:
# np.float64(2.0)

# %%
# can call using pandas methods
series.mean()
# Out:
# np.float64(2.0)

# %%
series.index = [10, 20, 30, 40, 50]
series
# Out:
# 10    0
# 20    1
# 30    2
# 40    3
# 50    4
# dtype: int64

# %%
series.name = 'special series'
series
# Out:
# 10    0
# 20    1
# 30    2
# 40    3
# 50    4
# Name: special series, dtype: int64

# %%
series.dtype
# Out:
# dtype('int64')
