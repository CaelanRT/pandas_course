# %%
import pandas as pd
import numpy as np

# %%
my_series = pd.Series(range(5), index=['Monday', 'Tuesday', 'Wednesday', 'Thursday', 'Friday'] )
my_series
# Out:
# Monday       0
# Tuesday      1
# Wednesday    2
# Thursday     3
# Friday       4
# dtype: int64

# %%
my_series.iloc[[1, 2, 4]]
# Out:
# Tuesday      1
# Wednesday    2
# Friday       4
# dtype: int64

# %%
my_series.iloc[1:4]
# Out:
# Tuesday      1
# Wednesday    2
# Thursday     3
# dtype: int64

# %%
my_series.loc['Monday': 'Wednesday']
# Out:
# Monday       0
# Tuesday      1
# Wednesday    2
# dtype: int64

# %%
#label based slicing
my_series.index = [0, 2, 3, 100, 5]

# %%
my_series.loc[0:5]
# Out:
# 0      0
# 2      1
# 3      2
# 100    3
# 5      4
# dtype: int64
