# %%
import pandas as pd
import numpy as np

# %%
my_series = pd.Series(range(5))
my_series
# Out:
# 0    0
# 1    1
# 2    2
# 3    3
# 4    4
# dtype: int64

# %%
my_series[3]
# Out:
# np.int64(3)

# %%
my_series[1::2]
# Out:
# 1    1
# 3    3
# dtype: int64

# %%
my_series = pd.Series(range(5), index=['Monday', 'Tuesday', 'Wednesday', 'Thursday', 'Friday'] )
my_series
# Out:
# Monday       0
# Tuesday      1
# Wednesday    2
# Thursday     3
# Friday       4
# dtype: int64

# %%
my_series['Tuesday':'Friday']
# Out:
# Tuesday      1
# Wednesday    2
# Thursday     3
# Friday       4
# dtype: int64
