# %%
import numpy as np

rng = np.random.default_rng(616)

inventory = rng.integers(0, 100, 10)

inventory
# Out:
# array([39, 39, 93, 86, 48, 46, 48, 30, 11, 57])

# %%
inventory - 24
# Out:
# array([ 15,  15,  69,  62,  24,  22,  24,   6, -13,  33])

# %%
inventory / 2
# Out:
# array([19.5, 19.5, 46.5, 43. , 24. , 23. , 24. , 15. ,  5.5, 28.5])

# %%
price = (rng.random(10) * 10).round(2)
price
# Out:
# array([2.26, 0.17, 8.52, 8.97, 8.06, 9.09, 3.71, 4.11, 3.  , 3.56])

# %%
(price * inventory).sum().round(2)
# Out:
# np.float64(3000.87)

# %%
inventory_list = list(inventory)
inventory_list
# Out:
# [np.int64(39),
#  np.int64(39),
#  np.int64(93),
#  np.int64(86),
#  np.int64(48),
#  np.int64(46),
#  np.int64(48),
#  np.int64(30),
#  np.int64(11),
#  np.int64(57)]
